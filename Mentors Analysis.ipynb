# %%
import pandas as pd

data = pd.read_csv('Mentors\' System - Timetable.csv')

# %%
data.head()
# Out:
#   Number  Mentor Info Unnamed: 2          ROTATION 1  Unnamed: 4  \
# 0    NaN          NaN        NaN      1:00  - 3:00           NaN
# 1    NaN  Mentor Name      Feild         Teams Names        Room
# 2      1  Lamiaa Zain      AI/ML          Innovate X  C121 Hatem
# 3    NaN          NaN        NaN         Geostormers  C121 Hatem
# 4    NaN          NaN        NaN  Aurora Skywatchers  C121 Hatem
#
#      Unnamed: 5      ROTATION 2  Unnamed: 7    Unnamed: 8  \
# 0           NaN     3:15 - 6:00         NaN           NaN
# 1  BREAK 15 MIN     Teams Names        Room  BREAK 60 MIN
# 2           NaN         Fire -X  C201 Hatem           NaN
# 3           NaN   FLAME WINNERS  C201 Hatem           NaN
# 4           NaN  AI Enthusiasts  C201 Hatem           NaN
#
#                 ROTATION 3 Unnamed: 10   Unnamed: 11          ROTATION 4  \
# 0              7:00 - 8:15         NaN           NaN        8:30 - 10:00
# 1              Teams Names        Room  BREAK 15 MIN         Teams Names
# ...
